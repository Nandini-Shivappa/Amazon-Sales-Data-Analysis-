# %% [markdown]
# <a href="https://colab.research.google.com/github/Nandini-Shivappa/Amazon-Sales-Data-Analysis-/blob/main/Amazon_Sales_Data_Analysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Amazon Sales Data Analysis using Python**

# %% [markdown]
# Import necessary libraries

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/Amazon Sale Report.csv")

# %%
data.shape
# Out:
# (128976, 21)

# %% [markdown]
# The data has 92119 rows and 21 columns

# %%
data.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by', 'New', 'PendingS'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  object
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  object
#  14  ship-state          128941 non-null  object
#  15  ship-postal-code    128941 non-null  float64
#  16  ship-country        128941 non-null  object
#  17  B2B                 128976 non-null  bool
#  18  fulfilled-by        39263 non-null   object
#  19  New                 0 non-null       float64
#  20  PendingS            0 non-null       float64
# dtypes: bool(1), float64(4), int64(2), object(14)
# memory usage: 19.8+ MB

# %%
data.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  currency  Amount    ship-city   ship-state ship-postal-code  \
# 0  ...       INR  647.62       MUMBAI  MAHARASHTRA         400081.0
# 1  ...       INR  406.00    BENGALURU    KARNATAKA         560085.0
# 2  ...       INR  329.00  NAVI MUMBAI  MAHARASHTRA         410210.0
# 3  ...       INR  753.33   PUDUCHERRY   PUDUCHERRY         605008.0
# 4  ...       INR  574.00      CHENNAI   TAMIL NADU         600073.0
#
#    ship-country    B2B  fulfilled-by New  PendingS
# 0            IN  False     Easy Ship NaN       NaN
# 1            IN  False     Easy Ship NaN       NaN
# 2            IN   True           NaN NaN       NaN
# 3            IN  False     Easy Ship NaN       NaN
# 4            IN  False           NaN NaN       NaN
#
# [5 rows x 21 columns]

# %%
data = data.drop(['New', 'PendingS'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  object
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  object
#  14  ship-state          128941 non-null  object
#  15  ship-postal-code    128941 non-null  float64
#  16  ship-country        128941 non-null  object
#  17  B2B                 128976 non-null  bool
#  18  fulfilled-by        39263 non-null   object
# dtypes: bool(1), float64(2), int64(2), object(14)
# memory usage: 17.8+ MB

# %%
data['Date']=pd.to_datetime(data['Date'])
# Out:
# <ipython-input-39-54a1eaf80efb>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date']=pd.to_datetime(data['Date'])

# %%
data
# Out:
#          index             Order ID       Date                        Status  \
# 0            0  405-8078784-5731545 2022-04-30                     Cancelled
# 1            1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146 2022-04-30                       Shipped
# 3            3  403-9615377-8133951 2022-04-30                     Cancelled
# 4            4  407-1069790-7240320 2022-04-30                       Shipped
# ...        ...                  ...        ...                           ...
# 128971  128970  406-6001380-7673107 2022-05-31                       Shipped
# 128972  128971  402-9551604-7544318 2022-05-31                       Shipped
# 128973  128972  407-9547469-3152358 2022-05-31                       Shipped
# 128974  128973  402-6184140-0545956 2022-05-31                       Shipped
# 128975  128974  408-7436540-8728312 2022-05-31                       Shipped
#
#        Fulfilment Sales Channel ship-service-level  Category Size  \
# 0        Merchant     Amazon.in           Standard   T-shirt    S
# 1        Merchant     Amazon.in           Standard     Shirt  3XL
# 2          Amazon     Amazon.in          Expedited     Shirt   XL
# 3        Merchant     Amazon.in           Standard   Blazzer    L
# 4          Amazon     Amazon.in          Expedited  Trousers  3XL
# ...           ...           ...                ...       ...  ...
# 128971     Amazon     Amazon.in          Expedited     Shirt   XL
# 128972     Amazon     Amazon.in          Expedited   T-shirt    M
# 128973     Amazon     Amazon.in          Expedited   Blazzer  XXL
# 128974     Amazon     Amazon.in          Expedited   T-shirt   XS
# 128975     Amazon     Amazon.in          Expedited   T-shirt    S
#
#        Courier Status  Qty currency   Amount    ship-city    ship-state  \
# 0          On the Way    0      INR   647.62       MUMBAI   MAHARASHTRA
# 1             Shipped    1      INR   406.00    BENGALURU     KARNATAKA
# 2             Shipped    1      INR   329.00  NAVI MUMBAI   MAHARASHTRA
# 3          On the Way    0      INR   753.33   PUDUCHERRY    PUDUCHERRY
# 4             Shipped    1      INR   574.00      CHENNAI    TAMIL NADU
# ...               ...  ...      ...      ...          ...           ...
# 128971        Shipped    1      INR   517.00    HYDERABAD     TELANGANA
# 128972        Shipped    1      INR   999.00     GURUGRAM       HARYANA
# 128973        Shipped    1      INR   690.00    HYDERABAD     TELANGANA
# 128974        Shipped    1      INR  1199.00        Halol       Gujarat
# 128975        Shipped    1      INR   696.00       Raipur  CHHATTISGARH
#
#         ship-postal-code ship-country    B2B fulfilled-by
# 0               400081.0           IN  False    Easy Ship
# 1               560085.0           IN  False    Easy Ship
# 2               410210.0           IN   True          NaN
# 3               605008.0           IN  False    Easy Ship
# 4               600073.0           IN  False          NaN
# ...                  ...          ...    ...          ...
# 128971          500013.0           IN  False          NaN
# 128972          122004.0           IN  False          NaN
# 128973          500049.0           IN  False          NaN
# 128974          389350.0           IN  False          NaN
# 128975          492014.0           IN  False          NaN
#
# [128976 rows x 19 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  datetime64[ns]
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  object
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  object
#  14  ship-state          128941 non-null  object
#  15  ship-postal-code    128941 non-null  float64
#  16  ship-country        128941 non-null  object
#  17  B2B                 128976 non-null  bool
#  18  fulfilled-by        39263 non-null   object
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(2), object(13)
# memory usage: 17.8+ MB

# %%
data['Date'].min(),data['Date'].max()
# Out:
# (Timestamp('2022-03-31 00:00:00'), Timestamp('2022-06-29 00:00:00'))

# %% [markdown]
# ### Status Column

# %%
data.Status.unique()
# Out:
# array(['Cancelled', 'Shipped - Delivered to Buyer', 'Shipped',
#        'Shipped - Returned to Seller', 'Shipped - Rejected by Buyer',
#        'Shipped - Lost in Transit', 'Shipped - Out for Delivery',
#        'Shipped - Returning to Seller', 'Shipped - Picked Up', 'Pending',
#        'Pending - Waiting for Pick Up', 'Shipped - Damaged', 'Shipping'],
#       dtype=object)

# %%
data.value_counts('Status')
# Out:
# Status
# Shipped                          77815
# Shipped - Delivered to Buyer     28756
# Cancelled                        18334
# Shipped - Returned to Seller      1954
# Shipped - Picked Up                973
# Pending                            658
# Pending - Waiting for Pick Up      281
# Shipped - Returning to Seller      145
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipping                             8
# Shipped - Lost in Transit            5
# Shipped - Damaged                    1
# Name: count, dtype: int64

# %% [markdown]
# Fullfilment

# %%
data['Fulfilment'].unique()
# Out:
# array(['Merchant', 'Amazon'], dtype=object)

# %%
data.value_counts('Fulfilment')
# Out:
# Fulfilment
# Amazon      89713
# Merchant    39263
# Name: count, dtype: int64

# %%
fullfilment_df = data['Fulfilment'].value_counts().reset_index()

fullfilment_df['percentage']=np.round(100*fullfilment_df['count']/sum(fullfilment_df['count']),2)

# %%
status_count = sum(data.value_counts('Status'))

# %%
fullfilment_df
# Out:
#   Fulfilment  count  percentage
# 0     Amazon  89713       69.56
# 1   Merchant  39263       30.44

# %%
data['fullfilment-by'] = 'Some Value'

# %%
data[['Fulfilment','fullfilment-by']]
# Out:
#        Fulfilment fullfilment-by
# 0        Merchant     Some Value
# 1        Merchant     Some Value
# 2          Amazon     Some Value
# 3        Merchant     Some Value
# 4          Amazon     Some Value
# ...           ...            ...
# 128971     Amazon     Some Value
# 128972     Amazon     Some Value
# 128973     Amazon     Some Value
# 128974     Amazon     Some Value
# 128975     Amazon     Some Value
#
# [128976 rows x 2 columns]

# %%
data['fulfilled-by'].isnull().sum()
# Out:
# np.int64(89713)

# %%
data['fulfilled-by'].value_counts()
# Out:
# fulfilled-by
# Easy Ship    39263
# Name: count, dtype: int64

# %% [markdown]
# ## Sales Channel

# %%
data['Sales Channel'].unique()
# Out:
# array(['Amazon.in', 'Non-Amazon'], dtype=object)

# %%
data['Sales Channel'].value_counts()
# Out:
# Sales Channel
# Amazon.in     128852
# Non-Amazon       124
# Name: count, dtype: int64

# %%
data[data['Sales Channel']=='Non-Amazon']
# Out:
#          index             Order ID       Date   Status Fulfilment  \
# 938        937  S02-5278980-4327051 2022-04-30  Shipped     Amazon
# 1058      1057  S02-9107114-0460608 2022-04-30  Shipped     Amazon
# 3632      3631  S02-1006261-5356758 2022-04-28  Shipped     Amazon
# 3633      3632  S02-3681731-6111841 2022-04-28  Shipped     Amazon
# 3635      3634  S02-1926028-4838217 2022-04-28  Shipped     Amazon
# ...        ...                  ...        ...      ...        ...
# 118100  118099  S02-9176732-4357939 2022-06-08  Shipped     Amazon
# 124617  124616  S02-2059602-9568060 2022-06-04  Shipped     Amazon
# 124618  124617  S02-3811761-8377519 2022-06-04  Shipped     Amazon
# 124620  124619  S02-5216693-3162561 2022-06-04  Shipped     Amazon
# 124622  124621  S02-7324586-1573702 2022-06-04  Shipped     Amazon
#
#        Sales Channel ship-service-level Category  Size Courier Status  Qty  \
# 938       Non-Amazon           Standard   Wallet  Free      Unshipped   15
# 1058      Non-Amazon           Standard  T-shirt    XL      Unshipped    2
# 3632      Non-Amazon           Standard    Shirt     L      Unshipped    9
# 3633      Non-Amazon           Standard    Shirt     L      Unshipped    1
# 3635      Non-Amazon           Standard    Shirt    XS      Unshipped    1
# ...              ...                ...      ...   ...            ...  ...
# 118100    Non-Amazon           Standard  T-shirt     M      Unshipped    1
# 124617    Non-Amazon           Standard    Shirt     S      Unshipped    1
# 124618    Non-Amazon           Standard  T-shirt    XS      Unshipped    2
# 124620    Non-Amazon           Standard  T-shirt   XXL      Unshipped    1
# 124622    Non-Amazon           Standard  T-shirt   3XL      Unshipped    1
#
#        currency  Amount ship-city ship-state  ship-postal-code ship-country  \
# 938         NaN     NaN     Surat    Gujarat          394210.0           IN
# 1058        NaN     NaN     Surat    Gujarat          394210.0           IN
# 3632        NaN     NaN     Surat    Gujarat          394210.0           IN
# 3633        NaN     NaN     Surat    Gujarat          394210.0           IN
# 3635        NaN     NaN     Surat    Gujarat          394210.0           IN
# ...         ...     ...       ...        ...               ...          ...
# 118100      NaN     NaN     Surat    Gujarat          394210.0           IN
# 124617      NaN     NaN     Surat    Gujarat          394210.0           IN
# 124618      NaN     NaN     Surat    Gujarat          394210.0           IN
# 124620      NaN     NaN     Surat    Gujarat          394210.0           IN
# 124622      NaN     NaN     Surat    Gujarat          394210.0           IN
#
#           B2B fulfilled-by fullfilment-by
# 938     False          NaN     Some Value
# 1058    False          NaN     Some Value
# 3632    False          NaN     Some Value
# 3633    False          NaN     Some Value
# 3635    False          NaN     Some Value
# ...       ...          ...            ...
# 118100  False          NaN     Some Value
# 124617  False          NaN     Some Value
# 124618  False          NaN     Some Value
# 124620  False          NaN     Some Value
# 124622  False          NaN     Some Value
#
# [124 rows x 20 columns]

# %% [markdown]
# ### Ship Service Level

# %%
data['ship-service-level'].value_counts()
# Out:
# ship-service-level
# Expedited    88630
# Standard     40346
# Name: count, dtype: int64

# %% [markdown]
# ## Category

# %%
data['Category']
# Out:
# 0          T-shirt
# 1            Shirt
# 2            Shirt
# 3          Blazzer
# 4         Trousers
#             ...
# 128971       Shirt
# 128972     T-shirt
# 128973     Blazzer
# 128974     T-shirt
# 128975     T-shirt
# Name: Category, Length: 128976, dtype: object

# %%
data['Category'].value_counts()
# Out:
# Category
# T-shirt     50292
# Shirt       49877
# Blazzer     15500
# Trousers    10616
# Perfume      1157
# Wallet        926
# Socks         440
# Shoes         165
# Watch           3
# Name: count, dtype: int64

# %%
category_df = data[['Category', 'Qty', 'Amount']].groupby('Category').aggregate(sum)
# Out:
# <ipython-input-82-2090dccb59ea>:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   category_df = data[['Category', 'Qty', 'Amount']].groupby('Category').aggregate(sum)

# %%
category_df
# Out:
#             Qty       Amount
# Category
# Blazzer   13943  11215104.12
# Perfume    1051    789419.66
# Shirt     45044  21297770.08
# Shoes       153    124752.76
# Socks       399    150757.50
# T-shirt   45292  39206756.65
# Trousers   9898   5346286.30
# Wallet      863    458408.18
# Watch         3       915.00

# %%
category_df.sort_values('Qty', ascending=False)
# Out:
#             Qty       Amount
# Category
# T-shirt   45292  39206756.65
# Shirt     45044  21297770.08
# Blazzer   13943  11215104.12
# Trousers   9898   5346286.30
# Perfume    1051    789419.66
# Wallet      863    458408.18
# Socks       399    150757.50
# Shoes       153    124752.76
# Watch         3       915.00

# %%
category_df['avg price'] = np.round(category_df['Amount']/category_df['Qty'],2)
category_df
# Out:
#             Qty       Amount  avg price
# Category
# Blazzer   13943  11215104.12     804.35
# Perfume    1051    789419.66     751.11
# Shirt     45044  21297770.08     472.82
# Shoes       153    124752.76     815.38
# Socks       399    150757.50     377.84
# T-shirt   45292  39206756.65     865.64
# Trousers   9898   5346286.30     540.14
# Wallet      863    458408.18     531.18
# Watch         3       915.00     305.00

# %% [markdown]
# ### Category and Size

# %%
t_shirt_df = data[data['Category']== 'T-shirt']
t_shirt_df
# Out:
#          index             Order ID       Date     Status Fulfilment  \
# 0            0  405-8078784-5731545 2022-04-30  Cancelled   Merchant
# 5            5  404-1490984-4578765 2022-04-30    Shipped     Amazon
# 6            6  408-5748499-6859555 2022-04-30    Shipped     Amazon
# 8            8  407-5443024-5233168 2022-04-30  Cancelled     Amazon
# 13          13  408-7955685-3083534 2022-04-30    Shipped     Amazon
# ...        ...                  ...        ...        ...        ...
# 128969  128968  403-7059995-7618722 2022-05-31    Shipped     Amazon
# 128970  128969  404-3802633-7250760 2022-05-31  Cancelled     Amazon
# 128972  128971  402-9551604-7544318 2022-05-31    Shipped     Amazon
# 128974  128973  402-6184140-0545956 2022-05-31    Shipped     Amazon
# 128975  128974  408-7436540-8728312 2022-05-31    Shipped     Amazon
#
#        Sales Channel ship-service-level Category Size Courier Status  Qty  \
# 0          Amazon.in           Standard  T-shirt    S     On the Way    0
# 5          Amazon.in          Expedited  T-shirt   XL        Shipped    1
# 6          Amazon.in          Expedited  T-shirt    L        Shipped    1
# 8          Amazon.in          Expedited  T-shirt  3XL      Cancelled    0
# 13         Amazon.in          Expedited  T-shirt   XS        Shipped    1
# ...              ...                ...      ...  ...            ...  ...
# 128969     Amazon.in          Expedited  T-shirt   XL        Shipped    1
# 128970     Amazon.in          Expedited  T-shirt    M      Unshipped    1
# 128972     Amazon.in          Expedited  T-shirt    M        Shipped    1
# 128974     Amazon.in          Expedited  T-shirt   XS        Shipped    1
# 128975     Amazon.in          Expedited  T-shirt    S        Shipped    1
#
#        currency   Amount   ship-city     ship-state  ship-postal-code  \
# 0           INR   647.62      MUMBAI    MAHARASHTRA          400081.0
# 5           INR   824.00   GHAZIABAD  UTTAR PRADESH          201102.0
# 6           INR   653.00  CHANDIGARH     CHANDIGARH          160036.0
# 8           NaN      NaN   HYDERABAD      TELANGANA          500008.0
# 13          INR   657.00      MUMBAI    MAHARASHTRA          400053.0
# ...         ...      ...         ...            ...               ...
# 128969      INR   824.00       Delhi          DELHI          110053.0
# 128970      INR   612.00      MUMBAI    MAHARASHTRA          400017.0
# 128972      INR   999.00    GURUGRAM        HARYANA          122004.0
# 128974      INR  1199.00       Halol        Gujarat          389350.0
# 128975      INR   696.00      Raipur   CHHATTISGARH          492014.0
#
#        ship-country    B2B fulfilled-by fullfilment-by
# 0                IN  False    Easy Ship     Some Value
# 5                IN  False          NaN     Some Value
# 6                IN  False          NaN     Some Value
# 8                IN  False          NaN     Some Value
# 13               IN  False          NaN     Some Value
# ...             ...    ...          ...            ...
# 128969           IN  False          NaN     Some Value
# 128970           IN  False          NaN     Some Value
# 128972           IN  False          NaN     Some Value
# 128974           IN  False          NaN     Some Value
# 128975           IN  False          NaN     Some Value
#
# [50292 rows x 20 columns]

# %%
t_shirt_df.value_counts('Size')
# Out:
# Size
# M      9351
# L      8192
# XL     7573
# S      7509
# XXL    6166
# 3XL    5796
# XS     5515
# 6XL      81
# 5XL      61
# 4XL      48
# Name: count, dtype: int64

# %%
cat_size_df = data[['Category','Size']].value_counts().reset_index()
cat_size_df
# Out:
#     Category  Size  count
# 0    T-shirt     M   9351
# 1      Shirt     L   8924
# 2      Shirt    XL   8669
# 3      Shirt     M   8555
# 4    T-shirt     L   8192
# 5      Shirt   XXL   7652
# 6    T-shirt    XL   7573
# 7    T-shirt     S   7509
# 8    T-shirt   XXL   6166
# 9    T-shirt   3XL   5796
# 10     Shirt     S   5729
# 11     Shirt   3XL   5687
# 12   T-shirt    XS   5515
# 13     Shirt    XS   3136
# 14   Blazzer     L   2844
# 15   Blazzer     M   2588
# 16   Blazzer    XL   2380
# 17   Blazzer     S   2226
# 18   Blazzer   XXL   2119
# 19   Blazzer   3XL   1913
# 20  Trousers    XL   1856
# 21  Trousers     M   1821
# 22  Trousers   XXL   1796
# 23  Trousers     L   1775
# 24   Blazzer    XS   1430
# 25  Trousers     S   1238
# 26  Trousers   3XL   1183
# 27   Perfume  Free   1157
# 28  Trousers    XS    947
# 29    Wallet  Free    926
# 30     Shirt   6XL    657
# 31     Shirt   5XL    489
# 32     Shirt   4XL    379
# 33     Shoes  Free    165
# 34   T-shirt   6XL     81
# 35     Socks     S     74
# 36     Socks   XXL     73
# 37     Socks     L     72
# 38     Socks    XL     71
# 39     Socks   3XL     64
# 40   T-shirt   5XL     61
# 41     Socks     M     58
# 42   T-shirt   4XL     48
# 43     Socks    XS     28
# 44     Watch  Free      3

# %% [markdown]
# ## Courier Status

# %%
data['Courier Status']
# Out:
# 0         On the Way
# 1            Shipped
# 2            Shipped
# 3         On the Way
# 4            Shipped
#              ...
# 128971       Shipped
# 128972       Shipped
# 128973       Shipped
# 128974       Shipped
# 128975       Shipped
# Name: Courier Status, Length: 128976, dtype: object

# %%
data['Courier Status'].value_counts()
# Out:
# Courier Status
# Shipped       109486
# On the Way      6870
# Unshipped       6680
# Cancelled       5940
# Name: count, dtype: int64

# %%
courier_status_df = data['Courier Status'].value_counts().reset_index()

courier_status_df['percentage'] = np.round(100*courier_status_df['count']/sum(courier_status_df['count']), 2)
courier_status_df
# Out:
#   Courier Status   count  percentage
# 0        Shipped  109486       84.89
# 1     On the Way    6870        5.33
# 2      Unshipped    6680        5.18
# 3      Cancelled    5940        4.61

# %%
data[['Date', 'Amount']].groupby('Date').aggregate('sum').plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df = data[['Date', 'Amount']].groupby('Date').aggregate('sum')
df[df['Amount']==df['Amount'].max()]
# Out:
#                 Amount
# Date
# 2022-05-04  1209364.17

# %%
df[df['Amount']==df['Amount'].min()]
# Out:
#                Amount
# Date
# 2022-03-31  101683.85

# %% [markdown]
# ## Ship City

# %%
data['ship-city']
# Out:
# 0              MUMBAI
# 1           BENGALURU
# 2         NAVI MUMBAI
# 3          PUDUCHERRY
# 4             CHENNAI
#              ...
# 128971      HYDERABAD
# 128972       GURUGRAM
# 128973      HYDERABAD
# 128974          Halol
# 128975         Raipur
# Name: ship-city, Length: 128976, dtype: object

# %%
data['ship-city'].value_counts()
# Out:
# ship-city
# BENGALURU                    11208
# HYDERABAD                     8077
# MUMBAI                        6125
# NEW DELHI                     5792
# CHENNAI                       5430
#                              ...
# Nashik road                      1
# PHULPUR AZAMGARH DISTRICT        1
# MUMBAI,malad  east               1
# KOTHAPALLE, E.G.Dt               1
# shimoga                          1
# Name: count, Length: 8948, dtype: int64

# %%
top_10_ship_city = data['ship-city'].value_counts()[:10]
top_10_ship_city
# Out:
# ship-city
# BENGALURU    11208
# HYDERABAD     8077
# MUMBAI        6125
# NEW DELHI     5792
# CHENNAI       5430
# PUNE          3863
# KOLKATA       2380
# GURUGRAM      1865
# THANE         1701
# LUCKNOW       1462
# Name: count, dtype: int64

# %%
top_10_ship_city.plot(kind='bar')
# Out:
# <Axes: xlabel='ship-city'>

# %% [markdown]
# ## Ship State

# %%
data['ship-state']
# Out:
# 0          MAHARASHTRA
# 1            KARNATAKA
# 2          MAHARASHTRA
# 3           PUDUCHERRY
# 4           TAMIL NADU
#               ...
# 128971       TELANGANA
# 128972         HARYANA
# 128973       TELANGANA
# 128974         Gujarat
# 128975    CHHATTISGARH
# Name: ship-state, Length: 128976, dtype: object

# %%
top_10_ship_city.plot(kind='bar')[:10]
top_10_ship_state
# Out:
# ship-state
# MAHARASHTRA       22272
# KARNATAKA         17324
# TAMIL NADU        11488
# TELANGANA         11330
# UTTAR PRADESH     10646
# DELHI              6778
# KERALA             6577
# WEST BENGAL        5962
# ANDHRA PRADESH     5427
# Gujarat            4482
# Name: count, dtype: int64

# %%
top_10_ship_state.plot(kind='bar')
# Out:
# <Axes: xlabel='ship-state'>

# %%
data.value_counts('Status').plot(kind='bar')
# Out:
# <Axes: xlabel='Status'>

# %%
status_counts = data.value_counts('Status')
status_percentages = np.round(100 * status_counts / sum(status_counts), 2)

status_summary = pd.DataFrame({'count': status_counts, 'percentage': status_percentages})
print(status_summary)

status_counts.plot(kind='bar')
plt.show()
# Out:
#                                count  percentage
# Status
# Shipped                        77815       60.33
# Shipped - Delivered to Buyer   28756       22.30
# Cancelled                      18334       14.22
# Shipped - Returned to Seller    1954        1.52
# Shipped - Picked Up              973        0.75
# Pending                          658        0.51
# Pending - Waiting for Pick Up    281        0.22
# Shipped - Returning to Seller    145        0.11
# Shipped - Out for Delivery        35        0.03
# Shipped - Rejected by Buyer       11        0.01
# Shipping                           8        0.01
# Shipped - Lost in Transit          5        0.00
# Shipped - Damaged                  1        0.00
